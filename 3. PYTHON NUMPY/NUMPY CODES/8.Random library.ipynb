# %%
import numpy as np
np.random.rand()
# Out:
# 0.6715683573787693

# %%
np.random.randint(1,10)
# Out:
# 8

# %%
Arr =  np.random.randint(1,10,30)
print(Arr)
# Out:
# [9 6 9 7 3 9 8 4 2 8 8 3 1 8 8 4 4 2 1 7 9 3 4 7 3 9 8 5 6 6]

# %%
q = np.random.normal(loc=5000,scale=1000,size=10000)
print(q)
# Out:
# [5686.69155084 5662.2788419  4748.43293289 ... 4802.6033395  4004.17786787
#  3484.47458476]

# %%
import matplotlib.pyplot as plt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
np.ndarray.sort(q) # it permanantly sort q.

# %%
plt.hist(q,bins=50)
plt.show()
